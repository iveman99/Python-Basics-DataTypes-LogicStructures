# %%
# Basic Data Type in Python

# %%
num1 = 100
num2 = 200

# %%
type(num1)
# Out:
# int

# %%
id(num2)
# Out:
# 140707126234248

# %%
num2 = 500

# %%
id(num2)## Hence for for each data saved ID is created!
# Out:
# 2422518895760

# %%
type(num2)
# Out:
# int

# %%
id(num1)
# Out:
# 140707126231048

# %%
id(num2)
# Out:
# 2422518895760

# %%
num1+num2
# Out:
# 600

# %%
#Floating data

# %%
Float_x = 3.45

# %%
type(Float_x)
# Out:
# float

# %%
id(Float_x)
# Out:
# 2422517397328

# %%
Float_x
# Out:
# 3.45

# %%
print(Float_x)
# Out:
# 3.45

# %%
Float_x = 9.45

# %%
print(Float_x)
# Out:
# 9.45

# %%
Float_y = 10.3425

# %%
Float_x = Float_y

# %%
print(Float_x)
# Out:
# 10.3425

# %%
## String Variables

# %%
City = 'Mumbai'

# %%
State = "Maharastra"

# %%
len(City)
# Out:
# 6

# %%
print(State[0])
# Out:
# M

# %%
print(State[0:4])
# Out:
# Maha

# %%
print(State[0:8:2])
# Out:
# Mhrs

# %%
print(State[-2])
# Out:
# r

# %%
print(State[-2:])
# Out:
# ra

# %%
Message = "Making Data Speak"

# %%
len(Message)
# Out:
# 17

# %%
print(Message)
# Out:
# Making Data Speak

# %%
print(Message[7:])
# Out:
# Data Speak

# %%
#reverse Order

# %%
print(Message[-17:])
# Out:
# Making Data Speak

# %%
print(Message[-17:2])
# Out:
# Ma

# %%
print(Message[-17:7:])
# Out:
# Making

# %%
print(Message[::-1])
# Out:
# kaepS ataD gnikaM

# %%
type(Message)
# Out:
# str

# %%
#split function

# %%
words = Message.split(" ")

# %%
type(words)
# Out:
# list

# %%
print(words)
# Out:
# ['Making', 'Data', 'Speak']

# %%
print(words[2])
# Out:
# Speak

# %%
Country = "India,USA,UAE,Japan,China,Germany"

# %%
type(Country)
# Out:
# str

# %%
Country[0:8]
# Out:
# 'India,US'

# %%
len(Country)
# Out:
# 33

# %%
Country[10:13]
# Out:
# 'UAE'

# %%
Cr = Country.split(",")

# %%
Cr
# Out:
# ['India', 'USA', 'UAE', 'Japan', 'China', 'Germany']

# %%
Name = "University"

# %%
id(Name)
# Out:
# 2422533856176

# %%
Name = "Mumbai University"

# %%
id(Name)
# Out:
# 2422533857200

# %%
Name+" "+Country
# Out:
# 'Mumbai University India,USA,UAE,Japan,China,Germany'

# %%
X = 10

# %%
Y = 20

# %%
cond1 = X < Y

# %%
cond1
# Out:
# True

# %%
id(cond1)
# Out:
# 140707125316064

# %%
type(cond1)
# Out:
# bool

# %%
X = int(input("Enter a number: "))
Y = int(input("Enter a number: "))

if X>Y:
    print(X,"is Greater then Y")
elif X<Y:
    print(Y,"is Greater then X")
else:
    print("Oho")
# Out:
# Enter a number:  234
# Enter a number:  2
# 234 is Greater then Y

# %%
type(X)
# Out:
# int

# %%
X = int(input("Enter Number: "))
if X>1:
    print("This is Postive Number: ")
elif X<1:
    print("This is negative number: ")
else:
    print("This is neutral")
# Out:
# Enter Number:  -34
# This is negative number:

# %%
100%3 ==0
# Out:
# False

# %%
X = int(input("Enter a number: "))
if X%5==0:
    print(X," is is divisible by 5 ")
else:
    print(X," is not divisible by 5")
# Out:
# Enter a number:  08
# 8  is not divisible by 5

# %%
A = int(input("Enter a number: "))
B = int(input("Enter a number: "))
C = int(input("Enter a number: "))

if A>B and A>C:
    print(A," is greater then ",B,C)
elif B>A and B>C:
    print(B," is greater then ",A,C)
elif C>A and C>B:
    print(C," is greater then ",A,B)
else:
    print("Ohoo")
# Out:
# Enter a number:  1
# Enter a number:  2
# Enter a number:  3
# 3  is greater then  1 2

# %%
A = int(input("Enter a Number: "))
if A%3 == 0 or A%5 == 0:
    print(A," Is divisible by 3 or 5")
else:
    print("Not divisible")
# Out:
# Enter a Number:  33
# 33  Is divisible by 3 or 5

# %%
listt=["Mango","Apple","Chickoo","Orange","Pineapple","Avacoda"]

# %%
type(listt)
# Out:
# list

# %%
id(listt)
# Out:
# 2422534092864

# %%
print(listt[2])
# Out:
# Chickoo

# %%
print(listt[-1])
# Out:
# Avacoda

# %%
##Slicing

# %%
listt[0:3:2]
# Out:
# ['Mango', 'Chickoo']

# %%
listt[0:4]
# Out:
# ['Mango', 'Apple', 'Chickoo', 'Orange']

# %%
listt[0:]
# Out:
# ['Mango', 'Apple', 'Chickoo', 'Orange', 'Pineapple', 'Avacoda']

# %%
##printing Mango,Chickoo,Pineapple

# %%
listt[0:6:2]
# Out:
# ['Mango', 'Chickoo', 'Pineapple']

# %%
for i in range(0,4):
    print(listt[i])
# Out:
# Mango
# Apple
# Chickoo
# Orange

# %%
for x in listt:
    print(x)
# Out:
# Mango
# Apple
# Chickoo
# Orange
# Pineapple
# Avacoda

# %%
#print in reverse order

for i in range(5,-1,-1):
    print(listt[i])
# Out:
# Avacoda
# Pineapple
# Orange
# Chickoo
# Apple
# Mango

# %%
##Inserting new element in list

listt.append("Strawberry")

# %%
listt
# Out:
# ['Mango', 'Apple', 'Chickoo', 'Orange', 'Pineapple', 'Avacoda', 'Strawberry']

# %%
type(listt)
# Out:
# list

# %%
id(listt)
# Out:
# 2422534092864

# %%
#list of hetrogenouse mutable ordering!

# %%
student = [1,"Rohan","O+",[56,35,76]]

# %%
student
# Out:
# [1, 'Rohan', 'O+', [56, 35, 76]]

# %%
type(student)
# Out:
# list

# %%
type(student[0])
# Out:
# int

# %%
type(student[1])
# Out:
# str

# %%
type(student[2])
# Out:
# str

# %%
type(student[3])
# Out:
# list

# %%
print(student[3])
# Out:
# [56, 35, 76]

# %%
print(student[3][2])
# Out:
# 76

# %%
student.append("Sports")

# %%
student
# Out:
# [1, 'Rohan', 'O+', [56, 35, 76], 'Sports']

# %%
#imutable(id number is saved)
x = 10

# %%
id(x)
# Out:
# 140707126228168

# %%
x = 20

# %%
id(x)
# Out:
# 140707126228488

# %%
## Mutable

# %%
id(listt)
# Out:
# 2422534092864

# %%
listt
# Out:
# ['Mango', 'Apple', 'Chickoo', 'Orange', 'Pineapple', 'Avacoda', 'Strawberry']

# %%
listt.append("Watermelon")

# %%
listt
# Out:
# ['Mango',
#  'Apple',
#  'Chickoo',
#  'Orange',
#  'Pineapple',
#  'Avacoda',
#  'Strawberry',
#  'Watermelon']

# %%
print(listt)
# Out:
# ['Mango', 'Apple', 'Chickoo', 'Orange', 'Pineapple', 'Avacoda', 'Strawberry', 'Watermelon']

# %%
id(listt)
# Out:
# 2422534092864

# %%
address = ["Malad(West)","Mumbai","40064"]

# %%
type(address)
# Out:
# list

# %%
ad = 23,"34","adsd"

# %%
type(ad)
# Out:
# tuple

# %%
student.extend(address)

# %%
student
# Out:
# [1, 'Rohan', 'O+', [56, 35, 76], 'Sports', 'Malad(West)', 'Mumbai', '40064']

# %%
# Adding element in between the List

student = [1,"Rohan","O+",[56,35,76]]
address = ["Malad(West)","Mumbai","40064"]
student.extend(address)
student.insert(3,True)
print(student)
# Out:
# [1, 'Rohan', 'O+', True, [56, 35, 76], 'Malad(West)', 'Mumbai', '40064']

# %%
# Removing element in between the List
student.remove("O+")

# %%
student
# Out:
# [1, 'Rohan', True, [56, 35, 76], 'Malad(West)', 'Mumbai', '40064']

# %%
# Removing element in between the List with index

del student[2]

# %%
student
# Out:
# [1, 'Rohan', [56, 35, 76], 'Malad(West)', 'Mumbai', '40064']

# %%
#altertion we will update here the value for this
listt
# Out:
# ['Mango',
#  'Apple',
#  'Chickoo',
#  'Orange',
#  'Pineapple',
#  'Avacoda',
#  'Strawberry',
#  'Watermelon']

# %%
listt[1] = "AlterMango"

# %%
listt
# Out:
# ['Mango',
#  'AlterMango',
#  'Chickoo',
#  'Orange',
#  'Pineapple',
#  'Avacoda',
#  'Strawberry',
#  'Watermelon']

# %%
Fruit_name = str(input("Enter Fruit Name: "))
if Fruit_name in listt:
    print(Fruit_name," is in this list",listt.index(Fruit_name)+1," postion")
else:
    print(Fruit_name," is not in the list")
# Out:
# Enter Fruit Name:  23
# 23  is not in the list

# %%
Weights = [70,80,45,50]

# %%
maximum = max(Weights)
print(maximum)
# Out:
# 80

# %%
total = sum(Weights)
mean = total/len(Weights)
mean
# Out:
# 61.25

# %%
tuple_student = (1,"Rohan","o+",True,[56,78,39],"Malad(East)","Mumbai",40923)

# %%
tuple_student
# Out:
# (1, 'Rohan', 'o+', True, [56, 78, 39], 'Malad(East)', 'Mumbai', 40923)

# %%
type(tuple_student)
# Out:
# tuple

# %%
tuple_student[4][0] = 20
tuple_student[4][1] = 30
tuple_student[4][2] = 40

# %%
tuple_student
# Out:
# (1, 'Rohan', 'o+', True, [20, 30, 40], 'Malad(East)', 'Mumbai', 40923)

# %%
for i in tuple_student:
    print(i)
# Out:
# 1
# Rohan
# o+
# True
# [20, 30, 40]
# Malad(East)
# Mumbai
# 40923

# %%
## Dictonory

# %%
Student_dict = {"name": "Veman","rollno": 7,"City": "Bhiwandi","marks":[5,6,7,8,8]}

# %%
type(Student_dict)
# Out:
# dict

# %%
Student_dict.values()
# Out:
# dict_values(['Veman', 7, 'Bhiwandi', [5, 6, 7, 8, 8]])

# %%
id(Student_dict)
# Out:
# 2422535226432

# %%
Student_dict["marks"]
# Out:
# [5, 6, 7, 8, 8]

# %%
Student_dict
# Out:
# {'name': 'Veman', 'rollno': 7, 'City': 'Bhiwandi', 'marks': [5, 6, 7, 8, 8]}

# %%
Student_dict["rollno"]
# Out:
# 7

# %%
del Student_dict["City"]

# %%
Student_dict
# Out:
# {'name': 'Veman', 'rollno': 7, 'marks': [5, 6, 7, 8, 8]}

# %%
Student_dict.get("Veman","Not Found")
# Out:
# 'Not Found'
